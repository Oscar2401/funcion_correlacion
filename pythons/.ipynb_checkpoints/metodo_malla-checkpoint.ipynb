# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import time
import sys 
import math

# %%
data = np.loadtxt('/home/echeveste/mis_trabajos/correlation_f/data/data.dat')[:,:2]
rand = np.loadtxt('/home/echeveste/mis_trabajos/correlation_f/data/rand0.dat')[:,:2]

# %%
fig = plt.figure(figsize=(5,5))
plt.plot(data[:,0],data[:,1],'k,')

# %%
tam = 30
x = [i for i in range(math.floor(np.min(data[:,0])),math.ceil(np.max(data[:,0]))+tam,tam)]
y = [i for i in range(math.floor(np.min(data[:,1])),math.ceil(np.max(data[:,1]))+tam,tam)]

# %%
x_ = math.ceil((math.ceil(np.max(data[:,0])) - math.floor(np.min(data[:,0])))/tam)
y_ = math.ceil((math.ceil(np.max(data[:,1])) - math.floor(np.min(data[:,1])))/tam)

# %%
mallas = []
for i in range(len(x)-1):
    for j in range(len(y)-1):
        mallas.append(data[(data[:,0]>x[i])&(data[:,0]<x[i+1])&(data[:,1]>y[j])&(data[:,1]<y[j+1])])

# %%
x_min = np.min(x)
y_min = np.min(y)
x_max = np.max(x)
y_max = np.max(y)

# %%
a = np.array([x for i in range(len(x))]).reshape(len(x)*len(x))
b = np.array([j for j in y for i in x])
cub = np.stack((a,b), axis=0).T

# %%
cub = cub[(cub[:,0]!=x_min)&(cub[:,0]!=x_max)&(cub[:,1]!=y_min)&(cub[:,1]!=y_max)]

# %%
fig = plt.figure(figsize=(5,5))
for i in range(len(mallas)):
    plt.plot(mallas[i][:,0],mallas[i][:,1],',')
    plt.plot(cub[:,0],cub[:,1],'ko')
    if i <= 250/tam:
        plt.axvline(i*tam,ymin=0, ymax = 250, linewidth=1, color = 'k')
        plt.hlines(i*tam, xmin=0, xmax=250, linewidth=1, color = 'k')

# %%
cuad = []
lado = int(np.sqrt(len(mallas)))
for i in range(lado):
    for j in range(lado):
        cuad.append(np.array([[i*tam,j*tam],[(i+1)*tam,j*tam],[i*tam,(j+1)*tam],[(i+1)*tam,(j+1)*tam]]))

# %%
n = 0
m = 14
fig = plt.figure(figsize=(5,5))
for i in range(len(mallas)):
    plt.plot(mallas[n][:,0],mallas[n][:,1],',')
    plt.plot(mallas[m][:,0],mallas[m][:,1],',')
    plt.plot(cub[:,0],cub[:,1],'ko')
    plt.plot(cuad[n][:,0],cuad[n][:,1],'ro')
    plt.plot(cuad[m][:,0],cuad[m][:,1],'ro')
    if i <= 250/tam:
        plt.axvline(i*tam,ymin=0, ymax = 250, linewidth=1, color = 'k')
        plt.hlines(i*tam, xmin=0, xmax=250, linewidth=1, color = 'k')

# %% [markdown]
# # PRUEBA

# %%
def subdiv(data,tam):
    x = [i for i in range(math.floor(np.min(data[:,0])),math.ceil(np.max(data[:,0]))+tam,tam)]
    y = [i for i in range(math.floor(np.min(data[:,1])),math.ceil(np.max(data[:,1]))+tam,tam)]
    malla = []
    for i in range(len(x)-1):
        for j in range(len(y)-1):
            malla.append(data[(data[:,0]>x[i])&(data[:,0]<x[i+1])&(data[:,1]>y[j])&(data[:,1]<y[j+1])])
    
    cua_p = []
    lado = int(np.sqrt(len(malla)))
    for i in range(lado):
        for j in range(lado):
            cua_p.append(np.array([[i*tam,j*tam],[(i+1)*tam,j*tam],[i*tam,(j+1)*tam],[(i+1)*tam,(j+1)*tam]]))
    
    return malla,cua_p

# %%
def Histo_ani_XX(p,bn,point_max):
    
    # Iniciamos los arreglos los histogramas 
    NXX = np.zeros(bn)

    n = 0
    for ii in p:
        n = n+1
        # Histogramas XX
        s = ii-p[n:]
        dis, r = np.histogram(np.sqrt(s[:,0]**2+s[:,1]**2), bins=bn, range=(0, point_max))
        NXX = NXX + 2*dis
    return  NXX

# %%
def Histo_ani_XY(p,p_r,bn,point_max):
    NDR = np.zeros(bn)
    for ii in p:
        # Histogramas para DR
        s = ii-p_r
        dis, r = np.histogram(np.sqrt(s[:,0]**2+s[:,1]**2), bins=bn, range=(0, point_max))
        NDR = NDR + dis
    return NDR

# %%
def dis_min (p,p_r):
    dis = []
    for ii in p:
        # Histogramas para DR
        s = ii-p_r
        dis.append(np.min(np.sqrt(s[:,0]**2+s[:,1]**2)))
    
    return np.min(dis)

# %%
def Histo_mallas(data,tam,bn,point_max):
    
    malla_D, cua_p_D = subdiv(data,tam)
    
    NDD = np.zeros(bn)
    for i in range(len(malla_D)):
        NDD = NDD + Histo_ani_XX(malla_D[i],bn,point_max)
    
    for i in range(len(cua_p_D)-1):
        print(i)
        for j in range(i+1,len(cua_p_D)):
            
            if dis_min(cua_p_D[i],cua_p_D[j]) < point_max:
                NDD = NDD + Histo_ani_XY(malla_D[i],malla_D[j],bn,point_max)
    
    return NDD

# %%
tam = 30

start = time.perf_counter()

DD = Histo_mallas(data,tam,30,180)

finish = time.perf_counter()
print(f'Finializó en {round(finish-start,2)} segundos')
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# --------------------------------------------------------------------------
# KeyboardInterrupt                        Traceback (most recent call last)
# <ipython-input-63-e80b3df2ad83> in <module>
#       3 start = time.perf_counter()
#       4
# ----> 5 DD = Histo_mallas(data,tam,30,180)
#       6
#       7 finish = time.perf_counter()
#
# <ipython-input-62-7add675ebedf> in Histo_mallas(data, tam, bn, point_max)
#      12
#      13             if dis_min(cua_p_D[i],cua_p_D[j]) < point_max:
# ---> 14                 NDD = NDD + Histo_ani_XY(malla_D[i],malla_D[j],bn,point_max)
#      15
#      16     return NDD
#
# <ipython-input-27-6721e906ea87> in Histo_ani_XY(p, p_r, bn, point_max)
#       4         # Histogramas para DR
#       5         s = ii-p_r
# ----> 6         dis, r = np.histogram(np.sqrt(s[:,0]**2+s[:,1]**2), bins=bn, range=(0, point_max))
#       7         NDR = NDR + dis
#       8     return NDR
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     790     a, weights = _ravel_and_check_weights(a, weights)
#     791
# --> 792     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     793
#     794     # Histogram is an integer or a float array depending on the weights.
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     444
#     445         # bin edges must be computed
# --> 446         bin_edges = np.linspace(
#     447             first_edge, last_edge, n_equal_bins + 1,
#     448             endpoint=True, dtype=bin_type)
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     133     if div > 0:
#     134         step = delta / div
# --> 135         if _nx.any(step == 0):
#     136             # Special handling for denormal numbers, gh-5437
#     137             y /= div
#
# <__array_function__ internals> in any(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py in any(a, axis, out, keepdims)
#    2328
#    2329     """
# -> 2330     return _wrapreduction(a, np.logical_or, 'any', axis, None, out, keepdims=keepdims)
#    2331
#    2332
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83                 return reduction(axis=axis, dtype=dtype, out=out, **passkwargs)
#      84             else:
# ---> 85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
#      87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py in _any(a, axis, dtype, out, keepdims)
#      52
#      53 def _any(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 54     return umr_any(a, axis, dtype, out, keepdims)
#      55
#      56 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:

# %%
DD
# Out:
# array([1528354., 1066014.,  449542.,  516670.,  509059.,  466641.,
#         427378.,  399357.,  375313.,  353562.,  321235.,  292696.,
#         285651.,  279215.,  269178.,  262086.,  258325.,  257983.,
#         243329.,  236598.,  239345.,  237601.,  230281.,  215084.,
#         196064.,  199427.,  190053.,  180771.,  176176.,  177900.])
